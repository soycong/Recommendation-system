# %%
from sklearn.decomposition import TruncatedSVD
from scipy.sparse.linalg import svds
from datetime import datetime

import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df_ratings = pd.read_csv('data/ml-latest-small/ratings.csv')
df_movies = pd.read_csv('data/ml-latest-small/movies.csv')

# %% [markdown]
# ## Matrix Factorization using SVD
# with Feature scaling using Standardization
#
#  Standardization이 (X - X의 평균값) / (X의 표준편차) 이렇게 하는건데 여기서는 표준편차를 안 나눴네..? 나중에 해보자

# %%
def MatrixFactorizaion(df_ratings, df_movies):
    df_ratings = pd.read_csv('data/ml-latest-small/ratings.csv')
    df_movies = pd.read_csv('data/ml-latest-small/movies.csv')

    df_ratings=df_ratings[:2000000]
    df_movie_features = df_ratings.pivot(
        index='userId',
        columns='movieId',
        values='rating'
    ).fillna(0)
    
    ## Data normalizaiion ##
    # pivot table을 matrix로 변환
    R = df_movie_features.as_matrix()
    # 각 user들의 rating 평균을 구함
    user_ratings_mean = np.mean(R, axis = 1)
    # R_demeaned : 사용자-영화에 대해 사용자 평균 평점을 뺀 것.
    R_demeaned = R - user_ratings_mean.reshape(-1, 1)
    
    M_demeaned = pd.DataFrame(R_demeaned, columns = df_movie_features.columns)
    
    
    # U 행렬, sigma 행렬, V 전치 행렬을 반환.
    U, sigma, Vt = svds(M_demeaned, k = 50)
    # 0이 포함된 대칭행렬로 변환
    sigma = np.diag(sigma)
    
    # U, Sigma, Vt의 내적을 수행하면, 다시 원본 행렬로 복원 + 사용자 평균 rating을 적용 
    svd_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)
    
    preds_df = pd.DataFrame(all_user_predicted_ratings, columns = df_movie_features.columns)
    
    return preds_df

# %%
preds_df = MatrixFactorizaion(df_ratings, df_movies)
preds_df.head()
# Out:
# movieId    1         2         3         4         5         6         7       \
# 0       -0.054239  0.045130 -0.004835 -0.019817 -0.011284  0.041373 -0.007822
# 1        0.419835  1.406440 -0.188807  0.156658  0.268032  0.414698  0.052172
# 2        1.345619  0.266505 -0.011962  0.012278  0.079508  0.090960 -0.122094
# 3        1.133455  1.046982  0.141275  0.081841 -0.339675 -1.484659 -0.263096
# 4        1.389578  1.466495  0.605557 -0.029647  0.729380 -0.118539 -0.026017
#
# movieId    8         9         10      ...    161084    161155    161594  \
# 0       -0.017188  0.012246  0.037670  ... -0.005258 -0.005453  0.012369
# 1        0.044728 -0.020198  2.220256  ... -0.005909 -0.003974 -0.012555
# 2        0.031327 -0.018023  0.141176  ... -0.002647 -0.002364 -0.010153
# 3       -0.169750 -0.021862  1.611664  ...  0.020805  0.000410  0.056040
# 4        0.065577 -0.156655  0.307926  ... -0.007422 -0.011810  0.006644
#
# movieId    161830    161918    161944    162376    162542    162672    163949
# 0       -0.004991 -0.004639 -0.019055  0.021402 -0.006365 -0.006098 -0.004819
# 1       -0.003555 -0.002711 -0.071621 -0.016212  0.001047 -0.001468 -0.006577
# 2        0.000277 -0.000116 -0.018063 -0.015761  0.010611  0.006792 -0.006357
# 3       -0.002817 -0.000767  0.159159  0.087519 -0.030854 -0.021279  0.048529
# 4       -0.005159 -0.001249 -0.034658  0.016456  0.001710 -0.004166 -0.001864
#
# [5 rows x 9066 columns]

# %% [markdown]
# ## All user prediction system

# %%
def AllUserPrediction(preds_df, userID, df_movies, df_ratings, num_recommendations=5):
    df_ratings = pd.read_csv('data/ml-latest-small/ratings.csv')
    df_movies = pd.read_csv('data/ml-latest-small/movies.csv')

    user_row_number = userID - 1 # UserID starts at 1, not 0
    
    # 최종적으로 만든 pred_df에서 사용자 index에 따라 영화 데이터 정렬 -> 영화 평점이 높은 순으로 정렬
    sorted_user_predictions = preds_df.iloc[user_row_number].sort_values(ascending=False) # UserID starts at 1
    
    # 원본 평점 데이터에서 userId에 해당하는 데이터를 뽑아냄
    user_data = df_ratings[df_ratings.userId == (userID)]
    
    # 위에서 뽑은 user_data와 원본 영화 데이터를 합침
    user_full = (user_data.merge(df_movies, how = 'left', left_on = 'movieId', right_on = 'movieId').
                     sort_values(['rating'], ascending=False))
    user_full = user_data.merge(df_movies, on = 'movieId').sort_values(['rating'], ascending=False)
    
    # 원본 영화 데이터에서 사용자가 본 영화 데이터를 제외한 데이터를 추출
    recommendations = df_movies[~df_movies['movieId'].isin(user_full['movieId'])]
    # 사용자의 영화 평점이 높은 순으로 정렬된 데이터와 위 recommendations을 합친다. 
    recommendations = recommendations.merge( pd.DataFrame(sorted_user_predictions).reset_index(), on = 'movieId')
    # 컬럼 이름 바꾸고 정렬해서 return
    recommendations = recommendations.rename(columns = {user_row_number: 'Predictions'}).sort_values('Predictions', ascending = False).iloc[:num_recommendations, :]

    return recommendations

# %% [markdown]
# #### 330번 user에게 추천해줄 movie list

# %%
predictions = AllUserPrediction(preds_df, 330, df_movies, df_ratings, 10)
predictions.head()
# Out:
#      movieId                        title  \
# 246      296          Pulp Fiction (1994)
# 487      590    Dances with Wolves (1990)
# 294      356          Forrest Gump (1994)
# 40        47  Seven (a.k.a. Se7en) (1995)
# 316      380             True Lies (1994)
#
#                                        genres  Predictions
# 246               Comedy|Crime|Drama|Thriller     2.190762
# 487                   Adventure|Drama|Western     1.924099
# 294                  Comedy|Drama|Romance|War     1.732990
# 40                           Mystery|Thriller     1.579084
# 316  Action|Adventure|Comedy|Romance|Thriller     1.345957

# %% [markdown]
# ## Generate 'user - time(6hour term)' Matrix

# %%
def UserTimeMatrix(df_ratings):
    df_ratings = pd.read_csv('data/ml-latest-small/ratings.csv')
    
    # original dataframe에서 moiveId, rating, drop,
    rd = df_ratings
    rd.drop('movieId', axis = 1, inplace = True)
    rd.drop('rating', axis = 1, inplace = True)
    # timestamp2datetime
    rd['Hour_6']=[datetime.fromtimestamp(x).strftime('%H') for x in rd['timestamp']]
    rd.drop('timestamp', axis = 1, inplace = True)
    rd = rd.reindex(columns=['Hour_6','userId'])
    # datetime 기준으로 정렬
    rd = rd.sort_values(by='Hour_6')
    
    # datetime2Hour_6term
    rd.loc[(rd['Hour_6']=="00") | (rd["Hour_6"]=="01") | 
           (rd["Hour_6"]=="02") | (rd["Hour_6"]=="03"),"Hour_6"] = "h1"
    rd.loc[(rd['Hour_6']=="04") | (rd["Hour_6"]=="05") | 
           (rd["Hour_6"]=="06") | (rd["Hour_6"]=="07"),"Hour_6"] = "h2"
    rd.loc[(rd['Hour_6']=="08") | (rd["Hour_6"]=="09") | 
           (rd["Hour_6"]=="10") | (rd["Hour_6"]=="11"),"Hour_6"] = "h3"
    rd.loc[(rd['Hour_6']=="12") | (rd["Hour_6"]=="13") | 
           (rd["Hour_6"]=="14") | (rd["Hour_6"]=="15"),"Hour_6"] = "h4"
    rd.loc[(rd['Hour_6']=="16") | (rd["Hour_6"]=="17") | 
           (rd["Hour_6"]=="18") | (rd["Hour_6"]=="19"),"Hour_6"] = "h5"
    rd.loc[(rd['Hour_6']=="20") | (rd["Hour_6"]=="21") | 
           (rd["Hour_6"]=="22") | (rd["Hour_6"]=="23"),"Hour_6"] = "h6"
    
    return rd

# %%
M1 = UserTimeMatrix(df_ratings)
M1.head()
# Out:
#        Hour_6  userId
# 100003     h1     671
# 43614      h1     311
# 85514      h1     574
# 85513      h1     574
# 85512      h1     574

# %% [markdown]
# ## Generate 'user - prediction(top 5)' Matrix

# %%
def UserPredictionMatrix(predictions):
    user_title = {}
    for i in range(1, 672):
        predictions = AllUserPrediction(preds_df, i, df_movies, df_ratings, 10)
        df = predictions[:5]
        title = df[['title']]
        #title.drop(index='userId')
        title.reset_index(drop=True)
        title.rename(columns = {"title": i}, inplace = True)
        dict_from_df = title.to_dict('list')
        user_title.update(dict_from_df)
        df = pd.DataFrame(user_title)
        df = pd.DataFrame(list(user_title.items()),columns =['userId','title'])
    
    return df

# %%
M2 = UserPredictionMatrix(predictions)
M2.head()
# Out:
#    userId  \
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#
#                                                                                                                                                                                          title
# 0                                                               [Star Trek II: The Wrath of Khan (1982), Rocky (1976), Who Framed Roger Rabbit? (1988), Galaxy Quest (1999), Ladyhawke (1985)]
# 1                                                        [True Lies (1994), Shawshank Redemption, The (1994), Beauty and the Beast (1991), Stargate (1994), Ace Ventura: Pet Detective (1994)]
# 2  [Matrix, The (1999), Lord of the Rings: The Fellowship of the Ring, The (2001), Lord of the Rings: The Two Towers, The (2002), Star Wars: Episode IV - A New Hope (1977), Toy Story (1995)]
# 3                                                                     [Beauty and the Beast (1991), Raising Arizona (1987), Glory (1989), Platoon (1986), Monty Python's Life of Brian (1979)]
# 4                                                   [Men in Black (a.k.a. MIB) (1997), Sleepless in Seattle (1993), Incredibles, The (2004), Catch Me If You Can (2002), Groundhog Day (1993)]

# %% [markdown]
# -----

# %% [markdown]
# ### 00 ~ 04시간에 자주 시청하는 유저들 중  "Toy Story (1995)" 와 비슷한 취향을 가지고 있어(predict) 초대장을 보낼 유저들

# %%
def main(M1,M2):
    # Hour_6 변수 선언
    h1 = M1.loc[M1["Hour_6"] == "h1", :]  # h1 : 00 ~ 03
    h2 = M1.loc[M1["Hour_6"] == "h2", :]  # h2 : 04 ~ 07
    h3 = M1.loc[M1["Hour_6"] == "h3", :]  # h3 : 08 ~ 11
    h4 = M1.loc[M1["Hour_6"] == "h4", :]  # h4 : 12 ~ 15
    h5 = M1.loc[M1["Hour_6"] == "h5", :]  # h5 : 16  ~19
    h6 = M1.loc[M1["Hour_6"] == "h6", :]  # h6 : 20 ~ 23
    
    h1 = pd.merge(h1, M2, on="userId")
    h1 = h1.drop_duplicates(["userId"])
    print(h1)
    
    lst = ["Toy Story (1995)"] # filter list
    m = h1["title"].apply(lambda s: len(set(s) & set(lst)) > 0)
    
    return h1[m]

# %%
pd.set_option('display.max.colwidth', 200)
main(M1,M2)
# Out:
#       Hour_6  userId  \
# 0         h1     671
# 25        h1     311
# 178       h1     574
# 425       h1     299
# 714       h1     382
# 771       h1     111
# 1069      h1     612
# 1135      h1     529
# 1440      h1      22
# 1452      h1     380
# 1753      h1     213
# 2663      h1      23
# 2864      h1     502
# 2917      h1     173
# 2919      h1     369
# 2970      h1     580
# 3226      h1     105
# 3295      h1     225
# 3323      h1     300
# 3330      h1     607
# 3616      h1     177
# 3641      h1     509
# 3814      h1      24
# 3825      h1     176
# 3833      h1      61
# 3998      h1      86
# 4188      h1     624
# 4602      h1     569
# 4652      h1     384
# 4943      h1     295
# ...      ...     ...
# 18006     h1     292
# 18007     h1     488
# 18038     h1     471
# 18041     h1     571
# 18087     h1      87
# 18118     h1     572
# 18184     h1     339
# 18229     h1     336
# 18260     h1     189
# 18372     h1     363
# 18551     h1     564
# 18607     h1     208
# 18612     h1      71
# 18635     h1     373
# 18670     h1     530
# 18695     h1     371
# 18697     h1      54
# 18704     h1     346
# 18711     h1     347
# 18718     h1     340
# 18738     h1     222
# 18826     h1     216
# 18908     h1     303
# 18926     h1     309
# 18941     h1     598
# 18943     h1     375
# 18968     h1     181
# 18995     h1     510
# 18997     h1     224
# 18999     h1      45
#
#                                                                                                                                                                                                          title
# 0                      [Back to the Future (1985), Lord of the Rings: The Return of the King, The (2003), Star Wars: Episode VI - Return of the Jedi (1983), Memento (2000), Silence of the Lambs, The (1991)]
# 25                                                                                                      [Full Metal Jacket (1987), Taxi Driver (1976), Die Another Day (2002), Platoon (1986), Copycat (1995)]
# 178                                                                                       [Catch Me If You Can (2002), Donnie Darko (2001), Saving Private Ryan (1998), American History X (1998), 300 (2007)]
# 425                                                         [Jacob's Ladder (1990), Lord of the Rings: The Two Towers, The (2002), Jurassic Park (1993), Sixteen Candles (1984), Royal Tenenbaums, The (2001)]
# 714                                                                                   [Breakfast Club, The (1985), Wizard of Oz, The (1939), Chicago (2002), Legally Blonde (2001), Back to the Future (1985)]
# 771                      [Four Weddings and a Funeral (1994), Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000), Erin Brockovich (2000), Big Lebowski, The (1998), Independence Day (a.k.a. ID4) (1996)]
# 1069   [Lord of the Rings: The Return of the King, The (2003), Back to the Future (1985), Lord of the Rings: The Two Towers, The (2002), Forrest Gump (1994), Harry Potter and the Prisoner of Azkaban (2004)]
# 1135                                                                                                  [Monsters, Inc. (2001), Garden State (2004), Casino (1995), Bend It Like Beckham (2002), Ed Wood (1994)]
# 1440                               [Star Wars: Episode I - The Phantom Menace (1999), Braveheart (1995), Star Wars: Episode II - Attack of the Clones (2002), Total Recall (1990), Saving Private Ryan (1998)]
# 1452                                                                    [Anchorman: The Legend of Ron Burgundy (2004), Abyss, The (1989), Knight's Tale, A (2001), Eyes Wide Shut (1999), Hotel Rwanda (2004)]
# 1753                                                                                                        [Big Hero 6 (2014), Up (2009), Bridget Jones's Diary (2001), Cliffhanger (1993), Dark City (1998)]
# 2663                                                                                         [About Schmidt (2002), Young Frankenstein (1974), Donnie Brasco (1997), Few Good Men, A (1992), GoldenEye (1995)]
# 2864                                                             [Birdcage, The (1996), Star Trek: First Contact (1996), Big Lebowski, The (1998), Wallace & Gromit: The Wrong Trousers (1993), Ransom (1996)]
# 2917                                                                                      [Fargo (1996), Mission: Impossible (1996), Phenomenon (1996), Star Trek: First Contact (1996), Birdcage, The (1996)]
# 2919                                                          [Silence of the Lambs, The (1991), Crimson Tide (1995), Dumb & Dumber (Dumb and Dumber) (1994), Four Weddings and a Funeral (1994), Babe (1995)]
# 2970                                                              [Rear Window (1954), Harold and Kumar Go to White Castle (2004), Halloween (1978), Ponyo (Gake no ue no Ponyo) (2008), Lethal Weapon (1987)]
# 3226                                                                                                                     [Psycho (1960), Cast Away (2000), Witness (1985), Annie Hall (1977), Net, The (1995)]
# 3295                                                               [Shawshank Redemption, The (1994), Clear and Present Danger (1994), Speed (1994), Die Hard: With a Vengeance (1995), Mrs. Doubtfire (1993)]
# 3323                           [Matrix, The (1999), Star Wars: Episode V - The Empire Strikes Back (1980), Saving Private Ryan (1998), Independence Day (a.k.a. ID4) (1996), Men in Black (a.k.a. MIB) (1997)]
# 3330                                                                                                        [Heat (1995), Ed Wood (1994), Saving Private Ryan (1998), Stand by Me (1986), True Romance (1993)]
# 3616                                                               [Matrix, The (1999), Total Recall (1990), Mission: Impossible (1996), Enemy of the State (1998), Star Wars: Episode IV - A New Hope (1977)]
# 3641                                                                          [Harry Potter and the Chamber of Secrets (2002), Toy Story 2 (1999), What About Bob? (1991), Kalifornia (1993), Maverick (1994)]
# 3814                                                                              [Jurassic Park (1993), Braveheart (1995), Terminator 2: Judgment Day (1991), Silence of the Lambs, The (1991), Fargo (1996)]
# 3825                                                                                       [Fight Club (1999), Monsters, Inc. (2001), Forrest Gump (1994), Back to the Future (1985), Incredibles, The (2004)]
# 3833                                                                     [Toy Story (1995), Good Will Hunting (1997), Eternal Sunshine of the Spotless Mind (2004), Truman Show, The (1998), Apollo 13 (1995)]
# 3998                                                                      [Usual Suspects, The (1995), Fugitive, The (1993), Forrest Gump (1994), While You Were Sleeping (1995), English Patient, The (1996)]
# 4188                                                                                  [Maverick (1994), Road Warrior, The (Mad Max 2) (1981), Mad Max (1979), Femme Nikita, La (Nikita) (1990), Brazil (1985)]
# 4602                                                                                    [Schindler's List (1993), Citizen Kane (1941), Fugitive, The (1993), Chinatown (1974), Godfather: Part II, The (1974)]
# 4652                                                                      [Tomorrow Never Dies (1997), Austin Powers: The Spy Who Shagged Me (1999), Shaun of the Dead (2004), Desperado (1995), Dogma (1999)]
# 4943                                                                                          [Toy Story (1995), Groundhog Day (1993), Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Ghost (1990), Aliens (1986)]
# ...                                                                                                                                                                                                        ...
# 18006                                                                                                                      [Spider-Man (2002), Rock, The (1996), Memento (2000), Big (1988), Airplane! (1980)]
# 18007                                                       [Pulp Fiction (1994), Memento (2000), Big Lebowski, The (1998), Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Inglourious Basterds (2009)]
# 18038                                                                          [Braveheart (1995), Back to the Future (1985), E.T. the Extra-Terrestrial (1982), Die Hard (1988), Beauty and the Beast (1991)]
# 18041                                                                                   [Fight Club (1999), Pulp Fiction (1994), Cruel Intentions (1999), Independence Day (a.k.a. ID4) (1996), Clerks (1994)]
# 18087                                                                                          [Heat (1995), Dead Man Walking (1995), Ransom (1996), Star Trek: First Contact (1996), Grumpier Old Men (1995)]
# 18118                [Godfather: Part II, The (1974), Inception (2010), Seven (a.k.a. Se7en) (1995), Star Wars: Episode IV - A New Hope (1977), Pirates of the Caribbean: The Curse of the Black Pearl (2003)]
# 18184                                 [Lord of the Rings: The Fellowship of the Ring, The (2001), Silence of the Lambs, The (1991), Terminator 2: Judgment Day (1991), Pulp Fiction (1994), Fight Club (1999)]
# 18229  [Shawshank Redemption, The (1994), One Flew Over the Cuckoo's Nest (1975), Star Wars: Episode VI - Return of the Jedi (1983), Star Wars: Episode V - The Empire Strikes Back (1980), Silence of the ...
# 18260                                                                      [Shakespeare in Love (1998), Casino (1995), Star Wars: Episode I - The Phantom Menace (1999), Election (1999), Pulp Fiction (1994)]
# 18372                                                       [Men in Black (a.k.a. MIB) (1997), Toy Story 2 (1999), Shakespeare in Love (1998), Silence of the Lambs, The (1991), 2001: A Space Odyssey (1968)]
# 18551                                                                                 [Beautiful Mind, A (2001), Robin Hood: Men in Tights (1993), Dark Knight, The (2008), Shrek (2001), Finding Nemo (2003)]
# 18607                                                                    [Silence of the Lambs, The (1991), Godfather, The (1972), Usual Suspects, The (1995), Shawshank Redemption, The (1994), Fargo (1996)]
# 18612                                                                                     [Election (1999), Fargo (1996), Being John Malkovich (1999), Usual Suspects, The (1995), Shakespeare in Love (1998)]
# 18635                               [Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Goodfellas (1990), Groundhog Day (1993), Sixth Sense, The (1999), Full Monty, The (1997)]
# 18670                                                [Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Mission: Impossible (1996), Star Trek: First Contact (1996), Matrix, The (1999), Nutty Professor, The (1996)]
# 18695                                           [Schindler's List (1993), Godfather, The (1972), Gladiator (2000), Pirates of the Caribbean: The Curse of the Black Pearl (2003), Bourne Identity, The (2002)]
# 18697                                                                                      [Dark Knight, The (2008), Catch Me If You Can (2002), Iron Man (2008), Shutter Island (2010), Casino Royale (2006)]
# 18704                                       [Spirited Away (Sen to Chihiro no kamikakushi) (2001), Star Trek: First Contact (1996), Batman (1989), Superman (1978), Indiana Jones and the Last Crusade (1989)]
# 18711                                                           [Indiana Jones and the Last Crusade (1989), Gladiator (2000), Fight Club (1999), Shawshank Redemption, The (1994), Saving Private Ryan (1998)]
# 18718                      [Silence of the Lambs, The (1991), Lord of the Rings: The Return of the King, The (2003), Fight Club (1999), Saving Private Ryan (1998), Star Wars: Episode IV - A New Hope (1977)]
# 18738                                                                     [African Queen, The (1951), North by Northwest (1959), Rear Window (1954), 2001: A Space Odyssey (1968), Maltese Falcon, The (1941)]
# 18826                                     [Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001), Usual Suspects, The (1995), Shrek (2001), Indiana Jones and the Last Crusade (1989), Schindler's List (1993)]
# 18908                                                            [Ocean's Eleven (2001), Life Is Beautiful (La Vita è bella) (1997), Office Space (1999), Royal Tenenbaums, The (2001), Apocalypse Now (1979)]
# 18926                                                                              [Princess Bride, The (1987), Silence of the Lambs, The (1991), American History X (1998), Matrix, The (1999), Shrek (2001)]
# 18941                                                              [Groundhog Day (1993), Silence of the Lambs, The (1991), Reservoir Dogs (1992), Traffic (2000), Willy Wonka & the Chocolate Factory (1971)]
# 18943                                                                             [Shawshank Redemption, The (1994), Lion King, The (1994), Outbreak (1995), Crimson Tide (1995), Seven (a.k.a. Se7en) (1995)]
# 18968                                                                    [Usual Suspects, The (1995), Fight Club (1999), Seven (a.k.a. Se7en) (1995), Shawshank Redemption, The (1994), Godfather, The (1972)]
# 18995                                                                              [Godfather, The (1972), Usual Suspects, The (1995), Taxi Driver (1976), Godfather: Part II, The (1974), Sling Blade (1996)]
# 18997                                                                                        [Quiz Show (1994), Shawshank Redemption, The (1994), Batman (1989), Piano, The (1993), Dances with Wolves (1990)]
# 18999                                                                                [Being John Malkovich (1999), Rear Window (1954), North by Northwest (1959), Big Lebowski, The (1998), Casablanca (1942)]
#
# [264 rows x 3 columns]
#       Hour_6  userId  \
# 3833      h1      61
# 4943      h1     295
# 11014     h1     427
# 11404     h1     659
# 11734     h1     550
# 11975     h1     394
# 14581     h1     234
# 15338     h1     190
# 15525     h1     523
# 16624     h1     640
#
#                                                                                                                                                                         title
# 3833                                    [Toy Story (1995), Good Will Hunting (1997), Eternal Sunshine of the Spotless Mind (2004), Truman Show, The (1998), Apollo 13 (1995)]
# 4943                                                         [Toy Story (1995), Groundhog Day (1993), Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Ghost (1990), Aliens (1986)]
# 11014                               [Eternal Sunshine of the Spotless Mind (2004), Pianist, The (2002), Royal Tenenbaums, The (2001), High Fidelity (2000), Toy Story (1995)]
# 11404                [Toy Story (1995), Babe (1995), Beauty and the Beast (1991), Clear and Present Danger (1994), Interview with the Vampire: The Vampire Chronicles (1994)]
# 11734                               [Toy Story (1995), Star Wars: Episode IV - A New Hope (1977), Back to the Future (1985), Blade Runner (1982), Usual Suspects, The (1995)]
# 11975  [Lord of the Rings: The Return of the King, The (2003), Lord of the Rings: The Two Towers, The (2002), Toy Story (1995), American Beauty (1999), Jurassic Park (1993)]
# 14581                             [Back to the Future (1985), Lion King, The (1994), Eternal Sunshine of the Spotless Mind (2004), Toy Story (1995), Dark Knight, The (2008)]
# 15338                                                             [Fight Club (1999), Blair Witch Project, The (1999), Toy Story (1995), Bug's Life, A (1998), Casino (1995)]
# 15525                                                        [Schindler's List (1993), Back to the Future (1985), Saving Private Ryan (1998), Shrek (2001), Toy Story (1995)]
# 16624                                                       [Rock, The (1996), Toy Story (1995), Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Phenomenon (1996), Ransom (1996)]
